# %% [markdown]
# <a href="https://colab.research.google.com/github/alanayoung/BME3053C-Spring-2025/blob/main/baseballpitching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import pickle
with open("/Blaine_output.pkl", "rb") as file:
  data = pickle.load(file)

# %%
data.keys()
# Out:
# dict_keys(['cutter0_stretch', 'cutter1_stretch', 'fastball0_stretch', 'fastball0_windup', 'fastball1_stretch', 'fastball1_windup', 'fastball2_stretch', 'fastball3_stretch', 'fastball3_windup', 'fastball4_stretch', 'fastball4_windup', 'slider0_stretch', 'slider0_windup', 'slider1_stretch', 'slider1_windup', 'slider2_stretch', 'slider2_windup', 'splitter0_stretch', 'splitter1_stretch', 'splitter1_windup'])

# %%
data['cutter0_stretch'].keys()
# Out:
# dict_keys(['windup_index', 'foot_contact', 'max_shoulder_ext_rot', 'ball_release', 'follow_through', 'pelvis_velo', 'elbow_velo', 'wrist_velo', 'wrist_accel', 'shoulder_velo', 'elbow_disp', 'shoulder_disp', 'joint_dict', 'trunk', 'trunk_velo', 'joint_angle_dict', 'opencap_dict', 'elbow_torque', 'fc_max_pelvis', 'x_factor', 'trunk_elbow', 'shoulder_elbow', 'release_height_kine', 'max_pelvis_velo', 'max_trunk_velo', 'max_shoulder_velo', 'max_elbow_velo', 'joint_matrix', 'Pitch Type', 'Velocity', 'Notes', 'Release Height', 'Release Side', 'Extension', 'Vertical Movement(in)', 'Horizontal Movement(in)', 'Pitch Speed(mph)', 'Total Spin(rpm)', 'Tilt', 'Measured Tilt', 'Efficiency(%)', 'Active Spin(rpm)', 'GYRO'])

# %% [markdown]
# Plot a joint for all of the trials (joint angles are "X" "Y" "Z" where x is flx ext (in radians)

# %%
fig, ax = plt.subplots(figsize=(10,10))
for key in data.keys():
  ax.plot(data[key]["joint_dict"]["RElbow"]["X"], label=key)
ax.legend()
